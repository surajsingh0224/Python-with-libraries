# %%
# CREATING A DATA FRAME

# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]

# %%
df2 = pd.DataFrame(data_list)
df2
# Out:
#        0   1         2      3
# 0   John  28  New York  65000
# 1   Anna  34     Paris  70000
# 2  Peter  29    Berlin  62000
# 3  Linda  42    London  85000

# %%
columns = ["name", "age", "city", "salary"]
df2 = pd.DataFrame(data_list, columns= columns)
df2
# Out:
#     name  age      city  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
# SELECTING AND INDEXING OF THE COLUMNS

# %%
df2
# Out:
#     name  age      city  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
# SELECTING NAME AND CITY
df2[["name", "city"]]
# Out:
#     name      city
# 0   John  New York
# 1   Anna     Paris
# 2  Peter    Berlin
# 3  Linda    London

# %%
# SELECTING SALARY
df2["salary"]
# Out:
# 0    65000
# 1    70000
# 2    62000
# 3    85000
# Name: salary, dtype: int64

# %%
# CREATING A NEW COLUMN
df2["designation"] = ["Doctor", "Scientist", "Lawyer", "Graphic Designer"]

# %%
df2
# Out:
#     name  age      city  salary       designation
# 0   John   28  New York   65000            Doctor
# 1   Anna   34     Paris   70000         Scientist
# 2  Peter   29    Berlin   62000            Lawyer
# 3  Linda   42    London   85000  Graphic Designer

# %%
# REMOVING COLUMNS
df2.drop(["designation"], axis= 1, inplace= True) # inplace = True --> Removing the col permenantly
df2
# Out:
#     name  age      city  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
# REMOVING ROWS
df2.drop(3, axis= 0)
# Out:
#     name  age      city  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000

# %%
# SELECTING OF ROWS USING loc() FUNCTION
df2
# Out:
#     name  age      city  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2.loc[[0, 1]] # USING LIST OF LIST TO SELECT THE ROWS
# Out:
#    name  age      city  salary
# 0  John   28  New York   65000
# 1  Anna   34     Paris   70000

# %%
df.iloc[[2, 3]]
# Out:
#     Name  Age    City  Salary
# 2  Peter   29  Berlin   62000
# 3  Linda   42  London   85000

# %%
# SELECTING SUBSETS OF ROWS AND COLS
df2.loc[[0, 1]][["city", "salary"]]
# Out:
#        city  salary
# 0  New York   65000
# 1     Paris   70000

# %%
df2
# Out:
#     name  age      city  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2.loc[[2, 3]][["name", "age"]]
# Out:
#     name  age
# 2  Peter   29
# 3  Linda   42

# %%
# CONDITIONAL SELECTION

# %%
df2
# Out:
#     name  age      city  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
# SELECTING OF PEOPLE WHOSE AGE IS GREATER THAN 30
df2[df2["age"] > 30]
# Out:
#     name  age    city  salary
# 1   Anna   34   Paris   70000
# 3  Linda   42  London   85000

# %%
# SELECTING OF PEOPLE WHOSE AGE IS GREATER THAN 30 AND ONLY LIVE IN PARIS
df2[(df2["age"] > 30) & (df2["city"] == "paris")]
# Out:
# Empty DataFrame
# Columns: [name, age, city, salary]
# Index: []

# %%
df2[(df2["age"] > 30) & (df2["city"] == 'Paris')] # USING & OPERATOR
# Out:
#    name  age   city  salary
# 1  Anna   34  Paris   70000
